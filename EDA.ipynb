# %%
import pandas as pd

# %%
dfs=pd.read_html('https://en.wikipedia.org/wiki/List_of_airline_codes')
dfs
# Out:
# [     IATA ICAO                                        Airline  Call sign  \
#  0     EVY  NaN        34 Squadron, Royal Australian Air Force  Australia
#  1     NaN  GNL                                    135 Airways    GENERAL
#  2      1A  NaN                          Amadeus IT Group S.A.        NaN
#  3      1B  NaN  Sabre travel network Asia-Pacific (ex-Abacus)        NaN
#  4      1E  NaN                                      Travelsky        NaN
#  ...   ...  ...                                            ...        ...
#  6268  NaN  CYN                             Zhongyuan Aviation  ZHONGYUAN
#  6269   3J  WZP                                            Zip     ZIPPER
#  6270   ZG  TZT                                   ZIPAIR Tokyo      ZIPPY
#  6271   Z4  OOM                                  Zoom Airlines       ZOOM
#  6272  NaN  ORZ                                          Zorex      ZOREX
#
#       Country/Region                                           Comments
# ...

# %%
country_code_df=dfs[0]
country_code_df.head()
# Out:
#   IATA ICAO                                        Airline  Call sign  \
# 0  EVY  NaN        34 Squadron, Royal Australian Air Force  Australia
# 1  NaN  GNL                                    135 Airways    GENERAL
# 2   1A  NaN                          Amadeus IT Group S.A.        NaN
# 3   1B  NaN  Sabre travel network Asia-Pacific (ex-Abacus)        NaN
# 4   1E  NaN                                      Travelsky        NaN
#
#   Country/Region                                           Comments
# 0            NaN                                                NaN
# 1  United States                                                NaN
# 2         Global           GDS and airline hosting system (CRS/PSS)
# 3           APAC                              Regional distribution
# 4          China  Local distribution system and hosting system (...

# %%
airline_df=pd.read_csv('data/airline-safety.csv')
airline_df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...

# %%
airline_df[airline_df['airline'].str.lower().str.contains('united')]
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 51  United / Continental*              7139291291               19
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 51                      8               319               14
#
#     fatal_accidents_00_14  fatalities_00_14
# 51                      2               109

# %%
combined_df=pd.merge(left=airline_df, right=country_code_df, left_on='airline', right_on='Airline')
combined_df
# Out:
#                 airline  avail_seat_km_per_week  incidents_85_99  \
# 0            Aer Lingus               320906734                2
# 1            Air Canada              1865253802                2
# 2            Air France              3004002661               14
# 3              Alitalia               698012498                7
# 4    All Nippon Airways              1841234177                3
# 5     Austrian Airlines               358239823                1
# 6               Avianca               396922563                5
# 7        China Airlines               813216487               12
# 8                Condor               417982610                2
# 9              Egyptair               557699891                8
# 10   Ethiopian Airlines               488560643               25
# 11              Finnair               506464950                1
# 12     Garuda Indonesia               613356665               10
# ...
